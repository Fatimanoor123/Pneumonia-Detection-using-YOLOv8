# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.0 MB/s eta 0:00:00
# ...

# %%
# !pip install kaggle
from google.colab import files
files.upload()   # Upload kaggle.json

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# !unzip chest-xray-pneumonia.zip -d chest_xray
# Out:
# ...
#      <input type="file" id="files-2a460463-f863-4c6d-8ad8-46f8c81f92dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a460463-f863-4c6d-8ad8-46f8c81f92dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=chest_xray epochs=20 imgsz=224
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.195 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/content/chest_xray/chest_xray/chest_xray epochs=20 imgsz=224
# Out:
# Ultralytics 8.3.195 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install --upgrade ultralytics

# %%
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !pip install torch==2.1.0+cu121 torchvision==0.16.1+cu121 torchaudio==2.1.1+cu121 --index-url https://download.pytorch.org/whl/cu121
# !pip install --upgrade ultralytics
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement torch==2.1.0+cu121 (from versions: 2.2.0+cu121, 2.2.1+cu121, 2.2.2+cu121, 2.3.0+cu121, 2.3.1+cu121, 2.4.0+cu121, 2.4.1+cu121, 2.5.0+cu121, 2.5.1+cu121)
# ERROR: No matching distribution found for torch==2.1.0+cu121
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.1.0+cu121 torchvision==0.16.1+cu121 torchaudio==2.1.1+cu121 --index-url https://download.pytorch.org/whl/cu121
# !pip install ultralytics --upgrade
# Out:
# Found existing installation: torch 2.8.0+cu126
# Uninstalling torch-2.8.0+cu126:
#   Successfully uninstalled torch-2.8.0+cu126
# Found existing installation: torchvision 0.23.0+cu126
# Uninstalling torchvision-0.23.0+cu126:
#   Successfully uninstalled torchvision-0.23.0+cu126
# Found existing installation: torchaudio 2.8.0+cu126
# Uninstalling torchaudio-2.8.0+cu126:
#   Successfully uninstalled torchaudio-2.8.0+cu126
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement torch==2.1.0+cu121 (from versions: 2.2.0+cu121, 2.2.1+cu121, 2.2.2+cu121, 2.3.0+cu121, 2.3.1+cu121, 2.4.0+cu121, 2.4.1+cu121, 2.5.0+cu121, 2.5.1+cu121)
# ERROR: No matching distribution found for torch==2.1.0+cu121
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.9/887.9 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/classify/train2/weights/best.pt")
results = model.predict("/content/chest_xray/chest_xray/test/PNEUMONIA/person100_bacteria_475.jpeg")  # replace with any test X-ray
results[0].show()  # Access the first item in the results list
# Out:
# image 1/1 /content/chest_xray/chest_xray/test/PNEUMONIA/person100_bacteria_475.jpeg: 224x224 PNEUMONIA 0.98, NORMAL 0.02, 2.8ms
# Speed: 10.0ms preprocess, 2.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# <PIL.Image.Image image mode=RGB size=1106x762>

# %%
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO("best.pt")

# Run inference on a sample X-ray image
results = model.predict(source="sample_images/test_xray.jpg", save=True)

# Print results summary
print("Inference completed. Check the 'runs/detect/' folder for output images.")
